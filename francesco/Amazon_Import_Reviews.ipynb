# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import gzip
import json

from amazonData import read_gz

from __future__ import division, print_function

# %%
print(", ".join(read_gz.categories))
# Out:
# Amazon_Instant_Video, Arts, Automotive, Baby, Beauty, Books, Cell_Phones_&_Accessories, Clothing_&_Accessories, Electronics, finefoods, Furniture, Gift_Cards, Gourmet_Foods, Health, Home_&_Kitchen, Industrial_&_Scientific, Jewelry, Kindle_Store, movies, Musical_Instruments, Music, Office_Products, Patio, Pet_Supplies, Shoes, Software, Sports_&_Outdoors, Tools_&_Home_Improvement, Toys_&_Games, Video_Games, Watches

# %%
gen = read_gz.parse('Jewelry')

# %%
df = pd.DataFrame([x for x in gen])
#Empty reviews appear as NaN. Remove NaN reviews:
df.text[df.text.isnull()] = ''

# %%
total = df.shape[0]
columns = df.columns
print("{0} observations\n".format(total), "Columns: "+", ".join(columns))
# Out:
# 58621 observations
#  Columns: helpfulness, price, productId, profileName, score, summary, text, time, title, userId

# %% [markdown]
# ###Review distribution
#
# Reviews split to the sides

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.hist(df.score, bins = [1,2,3,4,5,6])
plt.plot()
# Out:
# []

# %% [markdown]
# Average review length:

# %%
lengths = [len(x) for x in df.text]

# %%
pd.DataFrame(lengths).describe()
pd.DataFrame(np.log([x for x in lengths if x !=0])).describe()
# Out:
#                   0
# count  58621.000000
# mean       5.409456
# std        0.638160
# min        2.708050
# 25%        4.919981
# 50%        5.356586
# 75%        5.828946
# max        8.735525
#
# [8 rows x 1 columns]

# %%
short_review = [rev for rev in lengths if rev < 5000]
long_review  = [rev for rev in lengths if rev >= 5000]

# %%
plt.hist([np.log(x) for x in lengths if x!=0], bins = 100)
plt.show()

# %%
logs = np.array([np.log(x) for x in lengths if x!= 0])
m = logs.mean()
s = logs.std()
norm = (logs - m)/s
#plt.hist(norm, bins=100)
x = np.linspace(-6,6,100)
y = norm.pdf(x)
plt.plt(x,y)
plt.show()
norm(
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-e88ce236c222> in <module>()
#       5 #plt.hist(norm, bins=100)
#       6 x = np.linspace(-6,6,100)
# ----> 7 y = norm.pdf(x)
#       8 plt.plt(x,y)
#       9 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'pdf'

# %%
short_review = [rev for rev in lengths if rev < 500]

# %%
plt.hist(short_review, bins = 100)
plt.show()

# %%
df['rev_len'] = map(len, df.text)

# %%
dford = df.sort(columns='rev_len')[np.array(('score','rev_len'))]
dford.index = range(len(dford))

# %%
rates = {1:[], 2:[], 3:[], 4:[], 5:[]}
j = 0
k = 0
for i in xrange(100, 2000):
    while dford.rev_len[j] < i - 100:
        j += 1
    k = j
    while dford.rev_len[k] < i:
        k += 1
    y = dford[j:k].groupby('score').count().score
    tot = sum(y) or 1
    for t in range(1,6):
        if not t in y:
            y.set_value(t, 0)
        rates[t].append(y[t] / tot)

# %%
plt.plot(rates[1], label="1 star")
plt.plot(rates[2], label="2 star")
plt.plot(rates[3], label="3 star")
plt.plot(rates[4], label="4 star")
plt.plot(rates[5], label="5 star")
plt.legend()
plt.show()
