# %% [markdown]
# Import libraries

# %%
import matplotlib as mpl
import numpy as np
import pandas as pd
# Out:
# /home/yash/local-python/2.7.6/py-init-env/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
#temp = '/home/yash/yash_project/mortgage_data/%.txt'
#path = temp % 'sample_orig_2012'
#!wc -l $path

# %%
names =["FICO", "F_DATE", "FHB", "M_DATE", "MDMSA", "MIP", "UNITS", "OCC", "CLTV", "DTI", "UPB", "LTV", "R", "CHANNEL", "PPM", "MTYPE", "STATE", "PTYPE", "ZIP", "LOANSEQ", "LOANPURP", "LOANTERM", "NUMBORR", "SELLER", "SERVICES"]
sample_data=pd.read_csv('sample_orig_2012.txt',delimiter='|',names=names)

print sample_data.columns
# Out:
# Index([u'FICO', u'F_DATE', u'FHB', u'M_DATE', u'MDMSA', u'MIP', u'UNITS', u'OCC', u'CLTV', u'DTI', u'UPB', u'LTV', u'R', u'CHANNEL', u'PPM', u'MTYPE', u'STATE', u'PTYPE', u'ZIP', u'LOANSEQ', u'LOANPURP', u'LOANTERM', u'NUMBORR', u'SELLER', u'SERVICES'], dtype='object')

# %%
sample_data
#groupby('SF')
# Out:
#        FICO  F_DATE  FHB  M_DATE  MDMSA  MIP  UNITS OCC  CLTV DTI ...  MTYPE  \
# 0       770  201306  NaN  204305    NaN    0      1   O    40   5 ...  FIX30
# 1       773  201305    N  204304    NaN   25      1   O    90  38 ...  FIX30
# 2       808  201205    Y  204204    NaN    0      1   O    80  23 ...  FIX30
# 3       794  201304  NaN  204203    NaN    0      1   O    43  22 ...  FIX30
# 4       732  201301    N  204203    NaN    0      1   O    68  12 ...  FIX30
# 5       780  201302  NaN  204301    NaN    0      1   O    76  28 ...  FIX30
# 6       753  201302  NaN  204301    NaN    0      1   O    68  42 ...  FIX30
# 7       735  201212    N  204204    NaN    0      1   O    44  32 ...  FIX30
# 8       746  201212    N  204211    NaN   30      1   O    95  28 ...  FIX30
# 9       811  201205  NaN  204204    NaN    0      1   O    79   9 ...  FIX30
# 10      789  201212  NaN  204211    NaN    0      1   O    39  27 ...  FIX30
# ...

# %%
#s=Series(Sample_data)
sample_data.head(n=10)
# Out:
#    FICO  F_DATE  FHB  M_DATE  MDMSA  MIP  UNITS OCC  CLTV DTI ...  MTYPE  \
# 0   770  201306  NaN  204305    NaN    0      1   O    40   5 ...  FIX30
# 1   773  201305    N  204304    NaN   25      1   O    90  38 ...  FIX30
# 2   808  201205    Y  204204    NaN    0      1   O    80  23 ...  FIX30
# 3   794  201304  NaN  204203    NaN    0      1   O    43  22 ...  FIX30
# 4   732  201301    N  204203    NaN    0      1   O    68  12 ...  FIX30
# 5   780  201302  NaN  204301    NaN    0      1   O    76  28 ...  FIX30
# 6   753  201302  NaN  204301    NaN    0      1   O    68  42 ...  FIX30
# 7   735  201212    N  204204    NaN    0      1   O    44  32 ...  FIX30
# 8   746  201212    N  204211    NaN   30      1   O    95  28 ...  FIX30
# 9   811  201205  NaN  204204    NaN    0      1   O    79   9 ...  FIX30
#
#    STATE  PTYPE    ZIP       LOANSEQ LOANPURP LOANTERM NUMBORR  \
# 0     ID     SF  83600  F112Q1128017        N      360       2
# ...

# %%
print sample_data['FICO'].describe() 
sample_data['FICO'].hist(bins=50, alpha=0.5)
# Out:
# count    50000.000000
# mean       764.994080
# std         37.815849
# min        603.000000
# 25%        743.000000
# 50%        774.000000
# 75%        794.000000
# max        832.000000
# dtype: float64

# %%
print sample_data['UPB'].describe()
sample_data['UPB'].hist(bins=50, alpha=0.5)
# Out:
# count     50000.000000
# mean     243241.960000
# std      129076.613338
# min       20000.000000
# 25%      142000.000000
# 50%      218000.000000
# 75%      327000.000000
# max      960000.000000
# dtype: float64

# %%
bystate = sample_data.groupby('ID')

# %%
bystate.head(n=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a5049bb14135> in <module>()
# ----> 1 bystate.head(n=10)
#
# NameError: name 'bystate' is not defined
