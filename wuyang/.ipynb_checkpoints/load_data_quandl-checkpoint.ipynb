# %%
import Quandl
mydata = Quandl.get("GOOG/NASDAQ_MONT",trim_start="2012-01-01", authtoken="XANwfFd9CmdoE3PdFzRg")
mydata.to_csv('test.csv')
quandl_code = 'GOOG/NASDAQ_VNET'
print quandl_code
#i_data = Quandl.get(quandl_code, trim_start="2005-01-01", authtoken="XANwfFd9CmdoE3PdFzRg")
# Out:
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_MONT
# GOOG/NASDAQ_VNET

# %%
import pandas as pd
mydata = pd.read_csv('test.csv', index_col=0)

# %%
mydata[5:6]
# Out:
#              Open   High   Low  Close  Volume
# Date
# 2013-10-03  13.67  14.75  13.6   14.7   88040

# %%
# !ls -l
# Out:
# total 28
# -rw-r--r-- 1 wuyang users    28 Jun 10 11:27 authtoken.p
# -rw-r--r-- 1 wuyang users  2795 Jun 10 11:45 load_data_quandl.ipynb
# -rw-r--r-- 1 wuyang users 18592 Jun  9 16:15 nasdaqchinesecompanylist.csv

# %%
import Quandl
mydata = Quandl.get("QUANDL/USDCNY",trim_start="2012-01-01", authtoken="XANwfFd9CmdoE3PdFzRg")
# Out:
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  QUANDL/USDCNY

# %%
mydata
# Out:
#                Rate  High (est)  Low (est)
# Date
# 2012-01-02  6.35817      6.4295     6.2876
# 2012-01-03  6.35189      0.0000     0.0000
# 2012-01-04  6.33855      0.0000     0.0000
# 2012-01-05  6.32251      6.3987     6.2472
# 2012-01-06  6.31992      6.3943     6.2464
# 2012-01-09  6.32423      6.3973     6.2520
# 2012-01-10  6.32436      6.3977     6.2518
# 2012-01-11  6.31603      6.3903     6.2426
# 2012-01-12  6.31249      6.3840     6.2418
# 2012-01-13  6.31437      6.3902     6.2395
# 2012-01-16  6.31357      0.0000     0.0000
# 2012-01-17  6.31326      6.3879     6.2395
# 2012-01-18  6.30910      6.3872     6.2320
# 2012-01-19  6.30222      0.0000     0.0000
# 2012-01-20  6.29867      0.0000     0.0000
# 2012-01-23  6.30260      0.0000     0.0000
# 2012-01-24  6.30469      6.3749     6.2353
# 2012-01-25  6.30243      6.3751     6.2306
# 2012-01-26  6.30052      6.3716     6.2303
# 2012-01-27  6.29569      6.3723     6.2200
# 2012-01-30  6.29029      6.3614     6.2200
# 2012-01-31  6.29285      0.0000     0.0000
# 2012-02-01  6.29656      0.0000     0.0000
# 2012-02-02  6.29625      6.3702     6.2231
# 2012-02-03  6.29361      6.3671     6.2210
# 2012-02-06  6.29253      6.3658     6.2201
# 2012-02-07  6.29426      0.0000     0.0000
# 2012-02-08  6.29588      6.3743     6.2184
# 2012-02-09  6.29230      6.3642     6.2212
# 2012-02-10  6.28975      6.3594     6.2209
# ...             ...         ...        ...
# 2014-04-29  6.16791      6.2359     6.1006
# 2014-04-30  6.16324      0.0000     0.0000
# 2014-05-01  6.16365      6.2319     6.0962
# 2014-05-02  6.16280      0.0000     0.0000
# 2014-05-05  6.16204      6.2356     6.0893
# 2014-05-06  6.15926      0.0000     0.0000
# 2014-05-07  6.15450      0.0000     0.0000
# 2014-05-08  6.15451      6.2232     6.0866
# 2014-05-09  6.15422      6.2245     6.0848
# 2014-05-12  6.15690      0.0000     0.0000
# 2014-05-13  6.16236      0.0000     0.0000
# 2014-05-14  6.16645      6.2402     6.0935
# 2014-05-15  6.16779      6.2446     6.0919
# 2014-05-16  6.16803      6.2447     6.0923
# 2014-05-19  6.16747      6.2395     6.0962
# 2014-05-20  6.16747      0.0000     0.0000
# 2014-05-21  6.16752      0.0000     0.0000
# 2014-05-22  6.16805      6.2374     6.0994
# 2014-05-23  6.16759      0.0000     0.0000
# 2014-05-26  6.16961      6.2422     6.0979
# 2014-05-27  6.17288      0.0000     0.0000
# 2014-05-28  6.17449      6.2501     6.0997
# 2014-05-29  6.17449      0.0000     0.0000
# 2014-05-30  6.17317      6.2467     6.1005
# 2014-06-02  6.17123      6.2420     6.1013
# 2014-06-03  6.17171      0.0000     0.0000
# 2014-06-04  6.17290      6.2421     6.1044
# 2014-06-05  6.17271      0.0000     0.0000
# 2014-06-06  6.17204      0.0000     0.0000
# 2014-06-09  6.16462      0.0000     0.0000
#
# [636 rows x 3 columns]

# %%
START_DATE = "2005-01-01"
import pandas as pd
import Quandl
company_list = pd.read_csv('nasdaqchinesecompanylist.csv', index_col=0)
company_code = company_list.index
print len(company_code)
# Out:
# 118

# %%
NUM_DOWNLOADED = 0
FAILED_COMPANY = []
for i_company in xrange(0,len(company_code)-1):
    i_code = company_code[i_company]
    quandl_code = "GOOG/NASDAQ_" + i_code
    try:
        i_data = Quandl.get(quandl_code, trim_start=START_DATE, authtoken="XANwfFd9CmdoE3PdFzRg")
        NUM_DOWNLOADED = NUM_DOWNLOADED + 1
        i_data.to_csv(i_code + '.csv')
    except:
        FAILED_COMPANY.append(i_code)
print NUM_DOWNLOADED
print len(FAILED_COMPANY)
# Out:
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_VNET
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_JOBS
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_ACTS
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_AMCN
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_AMCF
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_ATAI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_AMAP
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_BIDU
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_BSPM
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_BONA
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CSIQ
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CYOU
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CHRM
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CADC
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CALI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CAAS
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CBAK
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CBPO
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CCCL
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CCCR
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_JRJC
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CHOP
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_HGSH
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CHLN
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CNIT
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CJJD
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_HTHT
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CREG
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CPGI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CSUN
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CXDC
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CNYD
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CCIH
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CNET
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CLNT
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CISG
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_CTRP
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_DHRM
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_EFUT
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_LONG
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_FFHL
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_GPRC
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_GURE
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_HSOL
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_HOLI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_HMIN
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_JASO
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_DATE
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_JST
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_KNDI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_KGJI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_KONE
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_KONG
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_KUTV
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_LIWA
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_MCOX
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_MONT
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_NTES
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_NFEC
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_OSN
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_PWRD
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_PME
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_QKLS
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_RCON
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_SGOC
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_GAME
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_SINA
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_SCOK
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_SVA
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_MOBI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_SPU
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_SKBI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_SOHU
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_SORL
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_GOMO
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_SUTR
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_NCTY
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_THTI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_OINK
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_UTSI
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_VIEW
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_VIMC
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_VISN
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_YONG
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_YY
# Token XANwfFd9CmdoE3PdFzRg activated and saved for later use.
# Returning Dataframe for
#  GOOG/NASDAQ_ZOOM
# 86

# %%
company_list.columns
# Out:
# Index([u'Name', u'LastSale', u'MarketCap', u'ADR TSO', u'Country', u'IPOyear', u'Sector', u'Industry', u'Summary Quote', u'Unnamed: 10'], dtype='object')

# %%
FAILED_COMPANY = []
FAILED_COMPANY.append('good')
print FAILED_COMPANY
# Out:
# ['good']

# %%
FAILED_COMPANY.append('bad')
print len(FAILED_COMPANY)
print FAILED_COMPANY
# Out:
# 2
# ['good', 'bad']
